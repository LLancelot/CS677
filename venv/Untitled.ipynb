# %%
for i in range(1,11):
    sum_of_length += len(locals()['ep'+str(i)])
    
avg_length = sum_of_length / 10

print(avg_length,sum_of_length)
# Out:
# (19, 195)

# %%
import sys

ep1 = "Lawnmower Dog"
ep2 = "Anatomy Park"
ep3 = "M. Night Shaym-Aliens!"
ep4 = "Meeseeks and Destroy"
ep5 = "Rick Potion #9"
ep6 = "Raising Gazorpazorp"
ep7 = "Rixty Minutes"
ep8 = "Something Ricked This Way Comes"
ep9 = "Close Rick-counters of the Rick Kind"
ep10 = "Ricksy Business"

sum_of_length = 0

# %%
locals()
# Out:
# {'In': ['',
#   u'ep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"',
#   u'ep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#   u"for i in range(1,11):\n    sum_of_length += len(local()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length)",
#   u'import sys\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#   u"for i in range(1,11):\n    sum_of_length += len(local()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length)",
#   u'import sys\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#   u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length)",
#   u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length,sum_of_length)",
#   u'import sys\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#   u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length,sum_of_length)",
#   u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length // 10\n\nprint(avg_length,sum_of_length)",
#   u'import sys\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#   u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length ./ 10\n\nprint(avg_length,sum_of_length)",
#   u'import sys\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#   u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length,sum_of_length)",
#   u'a = 2\nb = 3\nprint(a!=b)',
#   u'locals()',
#   u'import sys\n\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#   u'locals()'],
#  'Out': {17: {...}},
#  '_': {...},
#  '_17': {...},
#  '__': '',
#  '___': '',
#  '__builtin__': <module '__builtin__' (built-in)>,
#  '__builtins__': <module '__builtin__' (built-in)>,
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__name__': '__main__',
#  '__package__': None,
#  '_dh': [u'C:\\Users\\Lin\\PycharmProjects\\CS677\\venv'],
#  '_i': u'import sys\n\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#  '_i1': u'ep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"',
#  '_i10': u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length,sum_of_length)",
#  '_i11': u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length // 10\n\nprint(avg_length,sum_of_length)",
#  '_i12': u'import sys\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#  '_i13': u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length ./ 10\n\nprint(avg_length,sum_of_length)",
#  '_i14': u'import sys\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#  '_i15': u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length,sum_of_length)",
#  '_i16': u'a = 2\nb = 3\nprint(a!=b)',
#  '_i17': u'locals()',
#  '_i18': u'import sys\n\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#  '_i19': u'locals()',
#  '_i2': u'ep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#  '_i3': u"for i in range(1,11):\n    sum_of_length += len(local()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length)",
#  '_i4': u'import sys\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#  '_i5': u"for i in range(1,11):\n    sum_of_length += len(local()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length)",
#  '_i6': u'import sys\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#  '_i7': u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length)",
#  '_i8': u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length,sum_of_length)",
#  '_i9': u'import sys\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#  '_ih': ['',
#   u'ep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"',
#   u'ep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#   u"for i in range(1,11):\n    sum_of_length += len(local()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length)",
#   u'import sys\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#   u"for i in range(1,11):\n    sum_of_length += len(local()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length)",
#   u'import sys\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#   u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length)",
#   u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length,sum_of_length)",
#   u'import sys\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#   u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length,sum_of_length)",
#   u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length // 10\n\nprint(avg_length,sum_of_length)",
#   u'import sys\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#   u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length ./ 10\n\nprint(avg_length,sum_of_length)",
#   u'import sys\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#   u"for i in range(1,11):\n    sum_of_length += len(locals()['ep'+str(i)])\n    \navg_length = sum_of_length / 10\n\nprint(avg_length,sum_of_length)",
#   u'a = 2\nb = 3\nprint(a!=b)',
#   u'locals()',
#   u'import sys\n\nep1 = "Lawnmower Dog"\nep2 = "Anatomy Park"\nep3 = "M. Night Shaym-Aliens!"\nep4 = "Meeseeks and Destroy"\nep5 = "Rick Potion #9"\nep6 = "Raising Gazorpazorp"\nep7 = "Rixty Minutes"\nep8 = "Something Ricked This Way Comes"\nep9 = "Close Rick-counters of the Rick Kind"\nep10 = "Ricksy Business"\n\nsum_of_length = 0',
#   u'locals()'],
#  '_ii': u'locals()',
#  '_iii': u'a = 2\nb = 3\nprint(a!=b)',
#  '_oh': {17: {...}},
#  '_sh': <module 'IPython.core.shadowns' from 'c:\python27\lib\site-packages\IPython\core\shadowns.pyc'>,
#  'a': 2,
#  'avg_length': 19,
#  'b': 3,
#  'ep1': 'Lawnmower Dog',
#  'ep10': 'Ricksy Business',
#  'ep2': 'Anatomy Park',
#  'ep3': 'M. Night Shaym-Aliens!',
#  'ep4': 'Meeseeks and Destroy',
#  'ep5': 'Rick Potion #9',
#  'ep6': 'Raising Gazorpazorp',
#  'ep7': 'Rixty Minutes',
#  'ep8': 'Something Ricked This Way Comes',
#  'ep9': 'Close Rick-counters of the Rick Kind',
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x4eb8b88>,
#  'get_ipython': <bound method ZMQInteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x0000000004AB41C8>>,
#  'i': 10,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x4eb8b88>,
#  'sum_of_length': 0,
#  'sys': <module 'sys' (built-in)>}

# %%
# dictionary example
my_dict = {'apple':1, 'banana':3, 'Halsey':666}

print(my_dict['apple'])
print(my_dict['banana'])
print(my_dict['Halsey'])
# Out:
# 1
# 3
# 666
